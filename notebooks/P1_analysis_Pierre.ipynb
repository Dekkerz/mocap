# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
X_path = os.path.join('UT_Smoking_Data','Participant1_Data.xlsx')

# %%
data_1=pd.read_excel(X_path, header=None)
data_1
# Out:
#                    0          1         2         3         4         5   \
# 0       1455278271218  -5.973572 -6.710114  2.555145 -0.474457  0.382236
# 1       1455278271238  -5.980713 -6.838654  2.605133 -0.471420  0.249793
# 2       1455278271258  -6.025940 -6.895783  2.514679 -0.504273  0.187889
# 3       1455278271279  -5.956909 -7.031464  2.752716 -0.424346  0.048824
# 4       1455278271298  -5.959290 -6.900543  2.743195 -0.414628  0.176953
# ...               ...        ...       ...       ...       ...       ...
# 904395  1461602683308   9.681763 -1.978455 -0.256821 -0.134968 -0.414399
# 904396  1461602683329   9.865051 -1.980835 -0.268723  0.076663 -0.508131
# 904397  1461602683348  10.057861 -2.002258 -0.361557  0.315035 -0.547142
# 904398  1461602683369  10.045959 -1.964172 -0.349655  0.272425 -0.496381
# 904399  1461602683389   9.848389 -1.945129 -0.449631  0.069062 -0.442351
#
#               6         7         8         9   ...        22        23  \
# ...

# %%
d = {0:'timestamp_WD', 
     1:'Accelerometer_x_WD', 2:'Accelerometer_y_WD', 3:'Accelerometer_z_WD', 
     4:'Linear_acceleration_sensor_x_WD', 5:'Linear_acceleration_sensor_y_WD', 6:'Linear_acceleration_sensor_z_WD', 
     7:'Gyroscope_x_WD', 8:'Gyroscope_y_WD', 9:'Gyroscope_z_WD',
    10:'Magnetometer_x_WD', 11:'Magnetometer_y_WD', 12:'Magnetometer_z_WD', 
     13:'Pressure_sensor_WD', 14:'Heart_rate_sensor_WD',
    15:'GAP', 
     16:'timestamp_PD', 
     17:'Accelerometer_x_PD', 18:'Accelerometer_y_PD', 19:'Accelerometer_z_PD',
    20:'Linear_acceleration_sensor_x_PD', 21:'Linear_acceleration_sensor_y_PD', 22:'Linear_acceleration_sensor_z_PD', 
     23:'Gyroscope_x_PD', 24:'Gyroscope_y_PD',25:'Gyroscope_z_PD', 
     26:'Magnetometer_x_PD', 27:'Magnetometer_y_PD', 28:'Magnetometer_z_PD', 
     29:'GPS_lat_PD',30:'GPS_long_PD', 
     31:'Class_label'}

# %%
P1_data = data_1.rename(d, axis=1)

# %%
P1_data
# Out:
#          timestamp_WD  Accelerometer_x_WD  Accelerometer_y_WD  \
# 0       1455278271218           -5.973572           -6.710114
# 1       1455278271238           -5.980713           -6.838654
# 2       1455278271258           -6.025940           -6.895783
# 3       1455278271279           -5.956909           -7.031464
# 4       1455278271298           -5.959290           -6.900543
# ...               ...                 ...                 ...
# 904395  1461602683308            9.681763           -1.978455
# 904396  1461602683329            9.865051           -1.980835
# 904397  1461602683348           10.057861           -2.002258
# 904398  1461602683369           10.045959           -1.964172
# 904399  1461602683389            9.848389           -1.945129
#
#         Accelerometer_z_WD  Linear_acceleration_sensor_x_WD  \
# 0                 2.555145                        -0.474457
# 1                 2.605133                        -0.471420
# ...

# %%
P1_data.columns
# Out:
# Index(['timestamp_WD', 'Accelerometer_x_WD', 'Accelerometer_y_WD',
#        'Accelerometer_z_WD', 'Linear_acceleration_sensor_x_WD',
#        'Linear_acceleration_sensor_y_WD', 'Linear_acceleration_sensor_z_WD',
#        'Gyroscope_x_WD', 'Gyroscope_y_WD', 'Gyroscope_z_WD',
#        'Magnetometer_x_WD', 'Magnetometer_y_WD', 'Magnetometer_z_WD',
#        'Pressure_sensor_WD', 'Heart_rate_sensor_WD', 'GAP', 'timestamp_PD',
#        'Accelerometer_x_PD', 'Accelerometer_y_PD', 'Accelerometer_z_PD',
#        'Linear_acceleration_sensor_x_PD', 'Linear_acceleration_sensor_y_PD',
#        'Linear_acceleration_sensor_z_PD', 'Gyroscope_x_PD', 'Gyroscope_y_PD',
#        'Gyroscope_z_PD', 'Magnetometer_x_PD', 'Magnetometer_y_PD',
#        'Magnetometer_z_PD', 'GPS_lat_PD', 'GPS_long_PD', 'Class_label'],
#       dtype='object')

# %%
P1_data['Class_label'].value_counts()
# Out:
# SmokeSD    129200
# SmokeST    129200
# Eat        129200
# DrinkSD    129200
# DrinkST    129200
# Sit        129200
# Stand      129200
# Name: Class_label, dtype: int64

# %%
P1_data.isnull().sum()
# Out:
# timestamp_WD                            0
# Accelerometer_x_WD                      0
# Accelerometer_y_WD                      0
# Accelerometer_z_WD                      0
# Linear_acceleration_sensor_x_WD         0
# Linear_acceleration_sensor_y_WD         0
# Linear_acceleration_sensor_z_WD         0
# Gyroscope_x_WD                          0
# Gyroscope_y_WD                          0
# Gyroscope_z_WD                          0
# Magnetometer_x_WD                       0
# Magnetometer_y_WD                       0
# Magnetometer_z_WD                       0
# Pressure_sensor_WD                      0
# Heart_rate_sensor_WD                    0
# GAP                                904400
# timestamp_PD                            0
# Accelerometer_x_PD                      0
# Accelerometer_y_PD                      0
# Accelerometer_z_PD                      0
# Linear_acceleration_sensor_x_PD         0
# Linear_acceleration_sensor_y_PD         0
# ...

# %%
import datetime

# %%
P1_data[246490:246510, 1:3]
# Out:
#          timestamp_WD  Accelerometer_x_WD  Accelerometer_y_WD  \
# 246490  1454507506845           -8.213867            0.337646
# 246491  1454507506845           -8.213867            0.337646
# 246492  1454507506845           -8.213867            0.337646
# 246493  1454507506845           -8.213867            0.337646
# 246494  1454507506845           -8.213867            0.337646
# 246495  1454507506846           -8.213867            0.337646
# 246496  1454507506846           -8.213867            0.337646
# 246497  1454507506893           -8.113892            0.680420
# 246498  1454507506893           -8.113892            0.680420
# 246499  1454507506895           -8.113892            0.680420
# 246500             .c           -9.548889           -6.184051
# 246501  1458054662163           -9.548889           -6.184051
# 246502  1458054662181           -9.437012           -4.908173
# 246503  1458054662225           -7.085205           -1.394745
# ...

# %%
(246190-247910)/50
# Out:
# -34.4

# %%
plt.plot(P1_data.iloc[246190:247910, 16])

# %%
(246490-246510)/50
# Out:
# -0.4

# %%
plt.plot(P1_data.iloc[246490:246510, 1:4])

# %%
dtyp_time = P1_data.timestamp_WD.loc[P1_data.timestamp_WD!= len(range(13))]
dtyp_time
#df.loc[df['column_name'] != some_value]
# Out:
# 0         1455278271218
# 1         1455278271238
# 2         1455278271258
# 3         1455278271279
# 4         1455278271298
#               ...
# 904395    1461602683308
# 904396    1461602683329
# 904397    1461602683348
# 904398    1461602683369
# 904399    1461602683389
# Name: timestamp_WD, Length: 904400, dtype: object

# %%
P1_data.timestamp_WD.apply(lambda x: datetime.datetime.fromtimestamp(x/1000))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [38], line 1
# ----> 1 P1_data.timestamp_WD.apply(lambda x: datetime.datetime.fromtimestamp(x/1000))
#
# File ~/.pyenv/versions/3.10.6/envs/mocap/lib/python3.10/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/.pyenv/versions/3.10.6/envs/mocap/lib/python3.10/site-packages/pandas/core/apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
#    1104 # self.f is Callable
# ...

# %%
P1_data['Time_dates'] = P1_data['timestamp_WD'].map(lambda x: datetime.datetime.fromtimestamp(x/1000))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 P1_data['Time_dates'] = P1_data['timestamp_WD'].map(lambda x: datetime.datetime.fromtimestamp(x/1000))
#
# File ~/.pyenv/versions/3.10.6/envs/mocap/lib/python3.10/site-packages/pandas/core/series.py:4539, in Series.map(self, arg, na_action)
#    4460 def map(
#    4461     self,
#    4462     arg: Callable | Mapping | Series,
#    4463     na_action: Literal["ignore"] | None = None,
#    4464 ) -> Series:
#    4465     """
#    4466     Map values of Series according to an input mapping or function.
#    4467
#    (...)
#    4537     dtype: object
#    4538     """
# -> 4539     new_values = self._map_values(arg, na_action=na_action)
#    4540     return self._constructor(new_values, index=self.index).__finalize__(
#    4541         self, method="map"
#    4542     )
#
# ...

# %%
import tensorflow
from tensorflow.keras.utils import to_categorical
y = P1_data['Class_label']
y_cat = to_categorical(y)
y_cat.shape
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [76], line 1
# ----> 1 import tensorflow
#       2 from tensorflow.keras.utils import to_categorical
#       3 y = P1_data['Class_label']
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

target_encoder = OneHotEncoder(sparse = False).fit(data['Class_label']) 
y = target_encoder.transform(data['Class_label'])

# %%
#df_clear = P1_data.drop(P1_data[P1_data['timestamp_WD'].dtype =! int].index)
df_clear = P1_data[P1_data[['timestamp_WD']].apply(lambda x: x.isdigit(), axis=1)]
df_clear
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [85], line 2
#       1 #df_clear = P1_data.drop(P1_data[P1_data['timestamp_WD'].dtype =! int].index)
# ----> 2 df_clear = P1_data[P1_data[['timestamp_WD']].apply(lambda x: x.isdigit(), axis=1)]
#       3 df_clear
#
# File ~/.pyenv/versions/3.10.6/envs/mocap/lib/python3.10/site-packages/pandas/core/frame.py:9565, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9554 from pandas.core.apply import frame_apply
#    9556 op = frame_apply(
#    9557     self,
#    9558     func=func,
#    (...)
#    9563     kwargs=kwargs,
#    9564 )
# -> 9565 return op.apply().__finalize__(self, method="apply")
#
# File ~/.pyenv/versions/3.10.6/envs/mocap/lib/python3.10/site-packages/pandas/core/apply.py:746, in FrameApply.apply(self)
#     743 elif self.raw:
#     744     return self.apply_raw()
# ...

# %%
P1_data[P1_data[['timestamp_WD']].map(lambda x: x.isdigit(), axis=1)
# Out:
#   Cell In [86], line 1
#     P1_data[P1_data[['timestamp_WD']].map(lambda x: x.isdigit(), axis=1)
#                                                                         ^
# SyntaxError: incomplete input

# %%
clear = P1_data[~P1_data.timestamp_WD.str.contains('.c')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [87], line 1
# ----> 1 clear = P1_data[~P1_data.timestamp_WD.str.contains('.c')]
#
# File ~/.pyenv/versions/3.10.6/envs/mocap/lib/python3.10/site-packages/pandas/core/generic.py:1522, in NDFrame.__invert__(self)
#    1518 if not self.size:
#    1519     # inv fails with 0 len
#    1520     return self
# -> 1522 new_data = self._mgr.apply(operator.invert)
#    1523 return self._constructor(new_data).__finalize__(self, method="__invert__")
#
# File ~/.pyenv/versions/3.10.6/envs/mocap/lib/python3.10/site-packages/pandas/core/internals/managers.py:350, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     348 try:
#     349     if callable(f):
# --> 350         applied = b.apply(f, **kwargs)
#     351     else:
#     352         applied = getattr(b, f)(**kwargs)
#
# ...

# %%
pd.dtype(P1_data['timestamp_WD'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [92], line 1
# ----> 1 pd.dtype(P1_data['timestamp_WD'])
#
# File ~/.pyenv/versions/3.10.6/envs/mocap/lib/python3.10/site-packages/pandas/__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'dtype'

# %%
clear = P1_data.apply(P1_data.timestamp_WD.to_numeric).dropna()
clear
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [96], line 1
# ----> 1 clear = P1_data.apply(P1_data.timestamp_WD.to_numeric).dropna()
#       2 clear
#
# File ~/.pyenv/versions/3.10.6/envs/mocap/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'to_numeric'

# %%
P1_data.dtypes
# Out:
# timestamp_WD                        object
# Accelerometer_x_WD                 float64
# Accelerometer_y_WD                 float64
# Accelerometer_z_WD                 float64
# Linear_acceleration_sensor_x_WD    float64
# Linear_acceleration_sensor_y_WD    float64
# Linear_acceleration_sensor_z_WD    float64
# Gyroscope_x_WD                     float64
# Gyroscope_y_WD                     float64
# Gyroscope_z_WD                     float64
# Magnetometer_x_WD                  float64
# Magnetometer_y_WD                  float64
# Magnetometer_z_WD                  float64
# Pressure_sensor_WD                 float64
# Heart_rate_sensor_WD                 int64
# GAP                                float64
# timestamp_PD                         int64
# Accelerometer_x_PD                 float64
# Accelerometer_y_PD                 float64
# Accelerometer_z_PD                 float64
# Linear_acceleration_sensor_x_PD    float64
# Linear_acceleration_sensor_y_PD    float64
# ...

# %%
P1_data['Class_label'].value_counts()
# Out:
# SmokeSD    129200
# SmokeST    129200
# Eat        129200
# DrinkSD    129200
# DrinkST    129200
# Sit        129200
# Stand      129200
# Name: Class_label, dtype: int64

# %%
Basic_P1_DS = P1_data[P1_data['Class_label'].isin(['SmokeSD', 'SmokeST', 'Sit', 'Stand'])]

# %%
Basic_P1_DS
# Out:
#          timestamp_WD  Accelerometer_x_WD  Accelerometer_y_WD  \
# 0       1455278271218           -5.973572           -6.710114
# 1       1455278271238           -5.980713           -6.838654
# 2       1455278271258           -6.025940           -6.895783
# 3       1455278271279           -5.956909           -7.031464
# 4       1455278271298           -5.959290           -6.900543
# ...               ...                 ...                 ...
# 904395  1461602683308            9.681763           -1.978455
# 904396  1461602683329            9.865051           -1.980835
# 904397  1461602683348           10.057861           -2.002258
# 904398  1461602683369           10.045959           -1.964172
# 904399  1461602683389            9.848389           -1.945129
#
#         Accelerometer_z_WD  Linear_acceleration_sensor_x_WD  \
# 0                 2.555145                        -0.474457
# 1                 2.605133                        -0.471420
# ...

# %%
conditions = [
    (Basic_P1_DS['Class_label'] == 'SmokeSD') & (Basic_P1_DS['Class_label'] == 'SmokeST'),
    (Basic_P1_DS['Class_label'] == 'Sit') & (Basic_P1_DS['Class_label'] == 'Stand'),
]

values = [1, 0]

# %%
new = {'SmokeSD': 1,
'SmokeST': 1,
'Sit': 0,
'Stand': 0}

# %%
Basic_P1_DS['Basic_Class']  = np.select(conditions, values)
# Out:
# /var/folders/ky/75cz8yhx29j6w_ct3rvtgs4m0000gn/T/ipykernel_73660/3574944239.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Basic_P1_DS['Basic_Class']  = np.select(conditions, values)

# %%
Basic_P1_DS
# Out:
#          timestamp_WD  Accelerometer_x_WD  Accelerometer_y_WD  \
# 0       1455278271218           -5.973572           -6.710114
# 1       1455278271238           -5.980713           -6.838654
# 2       1455278271258           -6.025940           -6.895783
# 3       1455278271279           -5.956909           -7.031464
# 4       1455278271298           -5.959290           -6.900543
# ...               ...                 ...                 ...
# 904395  1461602683308            9.681763           -1.978455
# 904396  1461602683329            9.865051           -1.980835
# 904397  1461602683348           10.057861           -2.002258
# 904398  1461602683369           10.045959           -1.964172
# 904399  1461602683389            9.848389           -1.945129
#
#         Accelerometer_z_WD  Linear_acceleration_sensor_x_WD  \
# 0                 2.555145                        -0.474457
# 1                 2.605133                        -0.471420
# ...

# %%
Basic_P1_DS.drop(['Basic_Class'], axis=1)
# Out:
# /var/folders/ky/75cz8yhx29j6w_ct3rvtgs4m0000gn/T/ipykernel_73660/1220397418.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Basic_P1_DS.drop(['Basic_Class'], axis=1, inplace=True)

# %%
Basic_P1_DS
# Out:
#          timestamp_WD  Accelerometer_x_WD  Accelerometer_y_WD  \
# 0       1455278271218           -5.973572           -6.710114
# 1       1455278271238           -5.980713           -6.838654
# 2       1455278271258           -6.025940           -6.895783
# 3       1455278271279           -5.956909           -7.031464
# 4       1455278271298           -5.959290           -6.900543
# ...               ...                 ...                 ...
# 904395  1461602683308            9.681763           -1.978455
# 904396  1461602683329            9.865051           -1.980835
# 904397  1461602683348           10.057861           -2.002258
# 904398  1461602683369           10.045959           -1.964172
# 904399  1461602683389            9.848389           -1.945129
#
#         Accelerometer_z_WD  Linear_acceleration_sensor_x_WD  \
# 0                 2.555145                        -0.474457
# 1                 2.605133                        -0.471420
# ...

# %%
new = {'SmokeSD': 1,
'SmokeST': 1,
'Sit': 0,
'Stand': 0}

# %%
Basic_P1_DS['Basic_Class'] = Basic_P1_DS['Class_label'].map(new)
# Out:
# /var/folders/ky/75cz8yhx29j6w_ct3rvtgs4m0000gn/T/ipykernel_73660/3370533428.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Basic_P1_DS['Basic_Class'] = Basic_P1_DS['Class_label'].map(new)

# %%
Basic_P1_DS
# Out:
#          timestamp_WD  Accelerometer_x_WD  Accelerometer_y_WD  \
# 0       1455278271218           -5.973572           -6.710114
# 1       1455278271238           -5.980713           -6.838654
# 2       1455278271258           -6.025940           -6.895783
# 3       1455278271279           -5.956909           -7.031464
# 4       1455278271298           -5.959290           -6.900543
# ...               ...                 ...                 ...
# 904395  1461602683308            9.681763           -1.978455
# 904396  1461602683329            9.865051           -1.980835
# 904397  1461602683348           10.057861           -2.002258
# 904398  1461602683369           10.045959           -1.964172
# 904399  1461602683389            9.848389           -1.945129
#
#         Accelerometer_z_WD  Linear_acceleration_sensor_x_WD  \
# 0                 2.555145                        -0.474457
# 1                 2.605133                        -0.471420
# ...

# %%
Basic_P1_DS['Basic_Class'].value_counts()
# Out:
# 1    258400
# 0    258400
# Name: Basic_Class, dtype: int64

# %%
(258400*2)/50/16
# Out:
# 646.0

# %%
19*50
# Out:
# 950

# %%
P1_data.shape
# Out:
# (904400, 32)

# %%
904400/50/16
# Out:
# 1130.5

# %%
129200/50/19
# Out:
# 136.0

# %%
136/16
# Out:
# 8.5

# %%
136/18
# Out:
# 7.555555555555555

# %%
def window(df):
    for i in  
    df{i}= df.iloc[i:(i+950), :]

# %%
import mocap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [192], line 1
# ----> 1 import mocap
#
# ModuleNotFoundError: No module named 'mocap'
