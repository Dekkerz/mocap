# %%
import pandas as pd
import os

# %%
X_path = os.path.join('UT_Smoking_Data','Participant1_Data.xlsx')

# %%
# !pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 2.2 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.3.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
data_1=pd.read_excel(X_path, header=None)
data_1
# Out:
#                    0          1         2         3         4         5   \
# 0       1455278271218  -5.973572 -6.710114  2.555145 -0.474457  0.382236
# 1       1455278271238  -5.980713 -6.838654  2.605133 -0.471420  0.249793
# 2       1455278271258  -6.025940 -6.895783  2.514679 -0.504273  0.187889
# 3       1455278271279  -5.956909 -7.031464  2.752716 -0.424346  0.048824
# 4       1455278271298  -5.959290 -6.900543  2.743195 -0.414628  0.176953
# ...               ...        ...       ...       ...       ...       ...
# 904395  1461602683308   9.681763 -1.978455 -0.256821 -0.134968 -0.414399
# 904396  1461602683329   9.865051 -1.980835 -0.268723  0.076663 -0.508131
# 904397  1461602683348  10.057861 -2.002258 -0.361557  0.315035 -0.547142
# 904398  1461602683369  10.045959 -1.964172 -0.349655  0.272425 -0.496381
# 904399  1461602683389   9.848389 -1.945129 -0.449631  0.069062 -0.442351
#
#               6         7         8         9   ...        22        23  \
# ...

# %%
data_1.shape
# Out:
# (904400, 32)

# %%
data_1[:50]
# Out:
#                0         1          2         3         4         5   \
# 0   1455278271218 -5.973572  -6.710114  2.555145 -0.474457  0.382236
# 1   1455278271238 -5.980713  -6.838654  2.605133 -0.471420  0.249793
# 2   1455278271258 -6.025940  -6.895783  2.514679 -0.504273  0.187889
# 3   1455278271279 -5.956909  -7.031464  2.752716 -0.424346  0.048824
# 4   1455278271298 -5.959290  -6.900543  2.743195 -0.414628  0.176953
# 5   1455278271319 -5.847412  -6.676788  2.757477 -0.291596  0.390971
# 6   1455278271339 -5.878357  -6.722015  2.731293 -0.311381  0.332633
# 7   1455278271358 -5.942627  -6.807709  2.676544 -0.363410  0.239811
# 8   1455278271379 -5.937866  -7.136200  2.607513 -0.346733 -0.087040
# 9   1455278271398 -5.895020  -7.050507  2.597992 -0.294069  0.000549
# 10  1455278271419 -5.916443  -6.955292  2.583710 -0.305521  0.093607
# 11  1455278271438 -5.861694  -6.852936  2.683685 -0.240494  0.188380
# 12  1455278271458 -5.987854  -6.748200  2.564667 -0.354404  0.284655
# ...

# %%
data_1[31].value_counts()
# Out:
# SmokeSD    129200
# SmokeST    129200
# Eat        129200
# DrinkSD    129200
# DrinkST    129200
# Sit        129200
# Stand      129200
# Name: 31, dtype: int64

# %%
Data_2_path = os.path.join('UT_Smoking_Data','Participant1_Extra_SW_SG_W.xlsx')

# %%
data_2=pd.read_excel(Data_2_path, header=None)
data_2
# Out:
#                    0          1          2         3         4         5   \
# 0       1456400000000  -4.888123 -10.068817 -1.967560 -0.669430 -4.097033
# 1       1456400000000  -4.100220  -9.966461 -2.557892  0.125600 -4.007766
# 2       1456400000000  -4.431091  -7.474213 -2.177033 -0.191649 -1.523056
# 3       1456400000000  -4.942871  -5.938873 -2.655487 -0.685983  0.013065
# 4       1456400000000  -5.088074  -5.996002 -2.648346 -0.827633 -0.036409
# ...               ...        ...        ...       ...       ...       ...
# 387595  1455912036509  10.038818  -5.863220  1.783157  2.213460 -0.518417
# 387596  1455912036529  10.193542  -4.701599  1.690323  2.118495  0.212620
# 387597  1455912036549  11.521790  -4.380249  2.173538  3.122853 -0.055878
# 387598  1455912036570  10.617249  -5.303833  2.152115  2.044861 -1.310019
# 387599  1455912036589   9.846008  -6.127441  1.804581  1.154924 -2.367331
#
#               6         7         8         9   ...        22        23  \
# ...

# %%
data_2.shape
# Out:
# (387600, 32)

# %%
data_2[31].value_counts()
# Out:
# SmokeWK    129200
# Walk       129200
# SmokeGP    129200
# Name: 31, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data_1_SmokeSD = data_1.loc[data_1[31] == 'SmokeSD']
data_1_SmokeSD
# Out:
#                    0         1         2         3         4         5   \
# 0       1455278271218 -5.973572 -6.710114  2.555145 -0.474457  0.382236
# 1       1455278271238 -5.980713 -6.838654  2.605133 -0.471420  0.249793
# 2       1455278271258 -6.025940 -6.895783  2.514679 -0.504273  0.187889
# 3       1455278271279 -5.956909 -7.031464  2.752716 -0.424346  0.048824
# 4       1455278271298 -5.959290 -6.900543  2.743195 -0.414628  0.176953
# ...               ...       ...       ...       ...       ...       ...
# 129195  1455621991085  7.767944 -4.499268  0.007401  0.094020  1.162588
# 129196  1455621991134  8.615356 -4.684937 -0.363937  0.876325  0.884037
# 129197  1455621991134  8.615356 -4.684937 -0.363937  0.876325  0.884037
# 129198  1455621991134  8.615356 -4.684937 -0.363937  0.876325  0.884037
# 129199  1455621991184  8.315430 -5.096741 -0.337753  0.496988  0.366914
#
#               6         7         8         9   ...        22        23  \
# ...

# %%
plt.plot(data_1_SmokeSD.iloc[:1000, 9],'b', label="X" )

# %% [markdown]
# **Watch Data**

# %%
#Accelerometer(x,y,z)
plt.plot(data_1_SmokeSD.iloc[6000:6500, 1],'b', label="X" )
plt.plot(data_1_SmokeSD.iloc[6000:6500, 2],'g', label="Y" )
plt.plot(data_1_SmokeSD.iloc[6000:6500, 3],'r', label="Z" )

# %%
#Linear acceleration sensor(x,y,z)
plt.plot(data_1_SmokeSD.iloc[:1000, 4],'b', label="X" )
plt.plot(data_1_SmokeSD.iloc[:1000, 5],'g', label="Y" )
plt.plot(data_1_SmokeSD.iloc[:1000, 6],'r', label="Z" )

# %%
#Gyroscope(x,y,z)
plt.plot(data_1_SmokeSD.iloc[:1000, 7],'b', label="X" )
plt.plot(data_1_SmokeSD.iloc[:1000, 8],'g', label="Y" )
plt.plot(data_1_SmokeSD.iloc[:1000, 9],'r', label="Z" )

# %%
#magnetometer(x,y,z)
plt.plot(data_1_SmokeSD.iloc[6000:6500, 10],'b', label="X" )
plt.plot(data_1_SmokeSD.iloc[6000:6500, 11],'g', label="Y" )
plt.plot(data_1_SmokeSD.iloc[6000:6500, 12],'r', label="Z" )

# %%
#pressure
plt.plot(data_1_SmokeSD.iloc[:1000, 13],'b', label="X" )

# %%
#magnetometer(x,y,z)
plt.plot(data_1_SmokeSD.iloc[:100000, 14],'b', label="X" )

# %%
plt.plot(data_1_SmokeSD.iloc[:1000, 15],'b', label="X" )

# %% [markdown]
# **Phone Data**

# %%
plt.plot(data_1_SmokeSD.iloc[:1000, 17],'b', label="X" )
plt.plot(data_1_SmokeSD.iloc[:1000, 18],'g', label="Y" )
plt.plot(data_1_SmokeSD.iloc[:1000, 19],'r', label="Z" )

# %%
plt.plot(data_1_SmokeSD.iloc[:1000, 20],'b', label="X" )
plt.plot(data_1_SmokeSD.iloc[:1000, 21],'g', label="Y" )
plt.plot(data_1_SmokeSD.iloc[:1000, 22],'r', label="Z" )

# %%
plt.plot(data_1_SmokeSD.iloc[:1000, 23],'b', label="X" )
plt.plot(data_1_SmokeSD.iloc[:1000, 24],'g', label="Y" )
plt.plot(data_1_SmokeSD.iloc[:1000, 25],'r', label="Z" )

# %%
plt.plot(data_1_SmokeSD.iloc[:1000, 26],'b', label="X" )
plt.plot(data_1_SmokeSD.iloc[:1000, 27],'g', label="Y" )
plt.plot(data_1_SmokeSD.iloc[:1000, 28],'r', label="Z" )

# %%
plt.plot(data_1_SmokeSD.iloc[:1000, 29],'b', label="X" )

# %%
plt.plot(data_1_SmokeSD[0])

# %%
Data_10_path = os.path.join('UT_Smoking_Data','Participant10_Data.xlsx')

# %%
data_10=pd.read_excel(Data_10_path, header=None)
data_10
# Out:
#                    0          1         2         3         4         5   \
# 0       1456930000000  10.026917 -3.090088  0.700089  2.045898 -0.026381
# 1       1456930000000  10.026917 -3.090088  0.700089  2.045898 -0.026381
# 2       1456930000000  10.026917 -3.090088  0.700089  2.045898 -0.026381
# 3       1456930000000  11.617004 -7.362854  2.870987  2.898125 -2.786147
# 4       1456930000000  11.617004 -7.362854  2.870987  2.898125 -2.786147
# ...               ...        ...       ...       ...       ...       ...
# 412995  1461602747308   9.303284 -3.273376  0.152603  0.001466 -0.006599
# 412996  1461602747328   9.312805 -3.280518  0.178787  0.007633 -0.017115
# 412997  1461602747349   9.343750 -3.251953  0.195450 -0.009044  0.036479
# 412998  1461602747368   9.308044 -3.282898  0.152603 -0.009148  0.024417
# 412999  1461602747388   9.315186 -3.168640  0.100235  0.022995  0.053274
#
#               6         7         8         9   ...        22        23  \
# ...

# %%
data_10_SmokeSD = data_10.loc[data_1[31] == 'SmokeSD']
data_10_SmokeSD
# Out:
#                    0          1         2         3         4         5   \
# 0       1456930000000  10.026917 -3.090088  0.700089  2.045898 -0.026381
# 1       1456930000000  10.026917 -3.090088  0.700089  2.045898 -0.026381
# 2       1456930000000  10.026917 -3.090088  0.700089  2.045898 -0.026381
# 3       1456930000000  11.617004 -7.362854  2.870987  2.898125 -2.786147
# 4       1456930000000  11.617004 -7.362854  2.870987  2.898125 -2.786147
# ...               ...        ...       ...       ...       ...       ...
# 129195  1455107419296  -2.991333 -8.872009  1.426102  0.299008 -0.060305
# 129196  1455107419349  -2.796143 -9.517090  0.495377  0.235583 -0.538409
# 129197  1455107419349  -2.796143 -9.517090  0.495377  0.235583 -0.538409
# 129198  1455107419349  -2.796143 -9.517090  0.495377  0.235583 -0.538409
# 129199  1455107419405  -2.570007 -9.367126  0.088333  0.261699 -0.293016
#
#               6         7         8         9   ...        22        23  \
# ...

# %%
plt.plot(data_10_SmokeSD[0])

# %%
dt_data_10_SmokeSD = data_10_SmokeSD[0].map(lambda x: datetime.datetime.fromtimestamp(x/1000))
dt_data_10_SmokeSD.value_counts()
# Out:
# 2016-02-10 14:13:20.000    8600
# 2016-03-02 15:46:40.000    8400
# 2016-03-02 13:00:00.000    7400
# 2016-03-01 14:46:40.000    7250
# 2016-03-08 19:00:00.000    7250
#                            ...
# 2016-02-17 13:31:50.714       1
# 2016-02-17 13:31:50.857       1
# 2016-02-17 13:31:50.916       1
# 2016-02-17 13:31:51.091       1
# 2016-02-10 13:30:19.405       1
# Name: 0, Length: 51424, dtype: int64

# %%
import datetime

# %%
data_10[0].map(lambda x: datetime.datetime.fromtimestamp(x/1000))
# Out:
# 0        2016-03-02 15:46:40.000
# 1        2016-03-02 15:46:40.000
# 2        2016-03-02 15:46:40.000
# 3        2016-03-02 15:46:40.000
# 4        2016-03-02 15:46:40.000
#                    ...
# 412995   2016-04-25 18:45:47.308
# 412996   2016-04-25 18:45:47.328
# 412997   2016-04-25 18:45:47.349
# 412998   2016-04-25 18:45:47.368
# 412999   2016-04-25 18:45:47.388
# Name: 0, Length: 413000, dtype: datetime64[ns]

# %%
plt.plot(data_10[0].map(lambda x: datetime.datetime.fromtimestamp(x)))

# %%
data_10[0]
# Out:
# 0         1456930000000
# 1         1456930000000
# 2         1456930000000
# 3         1456930000000
# 4         1456930000000
#               ...
# 412995    1461602747308
# 412996    1461602747328
# 412997    1461602747349
# 412998    1461602747368
# 412999    1461602747388
# Name: 0, Length: 413000, dtype: int64

# %%
plt.plot(data_10[0])

# %%
time_1 = pd.to_datetime(data_10[0])
time_1
# Out:
# 0        1970-01-01 00:24:16.930000000
# 1        1970-01-01 00:24:16.930000000
# 2        1970-01-01 00:24:16.930000000
# 3        1970-01-01 00:24:16.930000000
# 4        1970-01-01 00:24:16.930000000
#                       ...
# 412995   1970-01-01 00:24:21.602747308
# 412996   1970-01-01 00:24:21.602747328
# 412997   1970-01-01 00:24:21.602747349
# 412998   1970-01-01 00:24:21.602747368
# 412999   1970-01-01 00:24:21.602747388
# Name: 0, Length: 413000, dtype: datetime64[ns]

# %%
dt_data_1_SmokeSD = data_1_SmokeSD[0].map(lambda x: datetime.datetime.fromtimestamp(x/1000))

# %%
plt.plot(dt_data_1_SmokeSD)

# %%
dt_data_1_SmokeSD.head(92)
# Out:
# 0    2016-02-12 12:57:51.218
# 1    2016-02-12 12:57:51.238
# 2    2016-02-12 12:57:51.258
# 3    2016-02-12 12:57:51.279
# 4    2016-02-12 12:57:51.298
#                ...
# 87   2016-02-12 12:57:52.998
# 88   2016-02-12 12:57:52.998
# 89   2016-02-12 12:57:52.998
# 90   2016-02-12 12:57:53.050
# 91   2016-02-12 12:57:53.071
# Name: 0, Length: 92, dtype: datetime64[ns]
